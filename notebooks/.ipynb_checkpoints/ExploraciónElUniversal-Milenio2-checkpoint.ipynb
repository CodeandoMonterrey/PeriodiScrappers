# %%
newspaper = {}

# %%
newspaper["searchUrl"] = "http://activo.eluniversal.com.mx/historico/search/index.php"
newspaper["searchParamType"] = "params"
newspaper["searchParam"] = "q"

# %%
searchData = {}

# %%
searchData["query"] = "Dragon Ball"

# %%
def buildBaseUrl(newspaper, searchData):
    if newspaper["searchParamType"] =="endpoint":
        url = newspaper["searchUrl"] + searchData["query"]
    else:
        #Case if searchParamType == get param
        url = newspaper["searchUrl"] +"?" + newspaper["searchParam"] + "=" + searchData["query"] 
    return url

# %%
buildBaseUrl(newspaper,searchData)
# Out:
# 'http://activo.eluniversal.com.mx/historico/search/index.php?q=fosas'

# %%
newspaper["paginationFirstParam"] = "False"
newspaper["paginationStrategy"] = "GET"
newspaper["paginationParams"] = {
    "startingPoint":{"name":"start","totalLocationName":"span#ContadorBusqueda", "totalLocationType":"HTML", "totalLocationOps":"locationText.split(' ')[0].replace('[','')", "sumFactor" :20 }, 
    "pageNumber":{"name":"page", "totalLocationName":"div.HojaBusqueda", "totalLocationType":"HTML", "totalLocationOps":"locationText.split(')')[0].split(" ")[-1]", "sumFactor": 1 }
    }
newspaper["visitType"] = "pureRequest"
newspaper["searchBody"] = "div#IzqDisplayColumn"
newspaper["articleBody"] = "div.apertura"

# %%
def buildPagination(newspaper, baseUrl, iterationParametersValues, iterationParameter):
    if newspaper["paginationStrategy"] == "GET":
        url, headers, formData = GETPagination(newspaper, baseUrl, iterationParametersValues, iterationParameter)
        print("Getting: "+ url)
        content = visitPage(url,newspaper) #TODO(ricalanis). Include headers and form data.
    #else newspaper["paginationStrategy"] == "POST/headers"
    return content

# %%
def GETPagination(newspaper, baseUrl, iterationParametersValues, iterationParameter):
    url = baseUrl
    firstParam = bool(newspaper["paginationFirstParam"])
    for numParam, param in enumerate(newspaper["paginationParams"]):
        if numParam == 0:
            if firstParam == "True":
                url = url + "?"
            else:
                url = url + "&"
        else:
            url = url + "&"
        url = url + newspaper["paginationParams"][param]["name"]  + "=" + str(iterationParametersValues[param])
    return url, [], []

# %%
from time import sleep

# %%
def searchPages(newspaper,searchData):
    searchPage = buildBaseUrl(newspaper,searchData)
    content = visitPage(searchPage, newspaper)
    maxValuesParams = extractMaxParamValue(content, newspaper)
    stories = []
    iterationMax, iterationParametersValues, iterationParameter = getIterationProcess(maxValuesParams, newspaper)
    while iterationParametersValues[iterationParameter] <= maxValuesParams[iterationParameter]:
        print(str(iterationParametersValues[iterationParameter]) + "/" + str(iterationMax))
        content =buildPagination(newspaper, searchPage, iterationParametersValues, iterationParameter)
        stories = stories + extractPageStories(content, newspaper, searchData)
        iterationParametersValues = incrementIterationParameters(iterationParametersValues, newspaper)
        sleep(0.5)
        print("Current story size:" + str(len(stories)))
    return stories

# %%
def incrementIterationParameters(iterationParametersValues, newspaper):
    for key in iterationParametersValues:
        print(newspaper["paginationParams"][key]["sumFactor"])
        iterationParametersValues[key] = iterationParametersValues[key] + newspaper["paginationParams"][key]["sumFactor"]
    return iterationParametersValues

# %%
def getIterationProcess(maxValuesParams, newspaper):
    iterationMax = 2
    sumFactor = 1
    if "pageNumber" in maxValuesParams:
        #TODO(ricalanis): Abstract this.
        iterationMax = maxValuesParams["pageNumber"]
        iterationParameter = "pageNumber"
    else:
        if "startingPoint" in maxValuesParams:
            iterationMax = maxValuesParams["startingPoint"]
            iterationParameter = "startingPoint"
    iterationParametersValues = {}
    for key in maxValuesParams:
        iterationParametersValues[key] = 1
    return iterationMax, iterationParametersValues, iterationParameter

# %%
#non iterative version:
def searchPage(newspaper,searchData):
    searchPage = buildBaseUrl(newspaper,searchData)
    content = visitPage(searchPage, newspaper)
    maxValuesParams = extractMaxParamValue(content, newspaper)
    currentPosition = 1
    stories = []
    stories = stories + extractPageStories(content, newspaper, searchData)
    return stories

# %%
searchPages(newspaper, searchData)
# Out:
# 1/8
# Getting: http://activo.eluniversal.com.mx/historico/search/index.php?q=Dragon Ball&page=1&start=1
# 1
# 20
# Current story size:20
# 2/8
# Getting: http://activo.eluniversal.com.mx/historico/search/index.php?q=Dragon Ball&page=2&start=21
# 1
# 20
# Current story size:40
# 3/8
# Getting: http://activo.eluniversal.com.mx/historico/search/index.php?q=Dragon Ball&page=3&start=41
# 1
# 20
# Current story size:60
# 4/8
# Getting: http://activo.eluniversal.com.mx/historico/search/index.php?q=Dragon Ball&page=4&start=61
# 1
# 20
# Current story size:80
# 5/8
# Getting: http://activo.eluniversal.com.mx/historico/search/index.php?q=Dragon Ball&page=5&start=81
# 1
# 20
# Current story size:100
# 6/8
# Getting: http://activo.eluniversal.com.mx/historico/search/index.php?q=Dragon Ball&page=6&start=101
# 1
# 20
# Current story size:120
# 7/8
# Getting: http://activo.eluniversal.com.mx/historico/search/index.php?q=Dragon Ball&page=7&start=121
# 1
# 20
# Current story size:140
# 8/8
# Getting: http://activo.eluniversal.com.mx/historico/search/index.php?q=Dragon Ball&page=8&start=141
# 1
# 20
# Current story size:153
# [{'link': 'http://www.eluniversal.com.mx/articulo/espectaculos/musica/2016/04/24/vibran-con-sabor-latino-del-vive',
#   'locationBody': "\n[email\xa0protected]/* <![CDATA[ */!function(t,e,r,n,c,a,p){try{t=document.currentScript||function(){for(t=document.getElementsByTagName('script'),e=t.length;e--;)if(t[e].getAttribute('data-cfhash'))return t[e]}();if(t&&(c=t.previousSibling)){p=t.parentNode;if(a=c.getAttribute('data-cfemail')){for(e='',r='0x'+a.substr(0,2)|0,n=2;a.length-n;n+=2)e+='%'+('0'+('0x'+a.substr(n,2)^r).toString(16)).slice(-2);p.replaceChild(document.createTextNode(decodeURIComponent(e)),c)}p.removeChild(t)}}catch(u){}}()/* ]]> */\nOchenta mil personas se dieron cita en el Foro Sol para disfrutar de la primera jornada del Vive Latino. La noche, el frío y hasta una pequeña lluvia no impidieron que el rock se manifestara en todo su esplendor con algunos de los exponentes más importantes de Iberoamérica.\nUno de ellos fue el cantante español Enrique Bunbury, que puso su toque al escenario principal cuando entre luces rojas y amarillas causó júbilo al salir al escenario a las 21:00 horas.\nVestido de negro y con su porte empezó su show con “Iberia sumergida”, de Héroes del Silencio.\n“Buenas no
#   'locationBody': "\n[email\xa0protected]/* <![CDATA[ */!function(t,e,r,n,c,a,p){try{t=document.currentScript||function(){for(t=document.getElementsByTagName('script'),e=t.length;e--;)if(t[e].getAttribute('data-cfhash'))return t[e]}();if(t&&(c=t.previousSibling)){p=t.parentNode;if(a=c.getAttribute('data-cfemail')){for(e='',r='0x'+a.substr(0,2)|0,n=2;a.length-n;n+=2)e+='%'+('0'+('0x'+a.substr(n,2)^r).toString(16)).slice(-2);p.replaceChild(document.createTextNode(decodeURIComponent(e)),c)}p.removeChild(t)}}catch(u){}}()/* ]]> */\nDos de las agrupaciones más populares del país del Sol Naciente pisaron foros de la Ciudad de México logrando llenos en sus respectivos recintos. Galneryus y FLOW, bandas de power metal y de rock-rap respectivamente, congregaron, entre ambos, alrededor de 2 mil fans en su primera visita a nuestro país y ellos lo agradecieron.\n“México y Tokio están alejados, pero unidos por el mismo cielo. Podemos conectarnos a través de la música”, expresó Keigo Hayashi, uno de los dos vocalistas de FLOW durante su presentación el miércoles en el Plaza Condesa, recinto en donde también se confesaron fans de la Selección mexicana de futbol y de jugadores como Javier Hernández El Chicharito, todo dicho en español.\nEl Plaza Condesa fue el recinto en el que la banda complació a fans con temas emblemáticos de su carrera como “Days”, “COLORS”, “Sign” “GO!!!” y “CHA-LA HEAD-CHA-LA”, tema de  Dragon Ball Z.\nGalneryus hizo lo suyo en el foro Indie Rocks, en donde deleitó a su audiencia con el poder de sus instrumentos en temas como “New Legend”, “The unbreakable”, “Raise my sword” y “Angel of Salvation”.\nEl grupo confesó que su visita a las pirámides de Teotihuacán le sirvió como inspiración para próximos temas.\n",
#   'locationTags': '\nRap y metal japonés ',
#   'locationTitle': '\n\nRap y metal japonés llegan a México\n\n',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversalqueretaro.mx/vida-q/09-08-2016/morko-y-mali-ofrece-diversion-infantil-mas-alla-de-pokemon',
#   'locationBody': '\nLa diversión infantil no sólo se basa en Pokémon, Dragon Ball o cualquier otro contenido proveniente de Asia.\nTamién existen transmisiones que apelan a la conservación del medio ambiente, el desarrollo de las facultades psicomotrices y hasta buscan hacer divertidas las matemáticas.\nUna de ellas es Morko & Mali, nueva producción de Disney Junior que estrenará el 16 de julio y que, a través de aventuras selváticas, busca crear conciencia sobre el planeta en los más pequeños del hogar.\nCon ayuda de elementos musicales y teniendo como fondo la selva del Amazonas, los protagonistas buscarán hacer divertidas aquellas cosas que en ocasiones a los niños les resultan no muy agradables.\n“Buscamos que los niños descubran que hay muchas cosas que desconocen y que pueden resultar divertidas, queremos que vean que salir a la naturaleza puede ser una gran aventura, que la imaginación es poderosa y que aprender cosas nuevas es muy entretenido”, dijo en su visita a México Agustina Vera, protagonista de la serie.\nEl programa de 26 capítulos fue grabado en Buenos Aires y cuenta con elementos de música pop y marionetas en forma de animales de la selva para hacer atractivo a los espectadores cada aventura de los protagonistas.\nJunto a Agustina, Tomás Ottaviano, quien interpreta a Morko, explicó que el programa infantil acercará a los niños a una diversión distinta en un panorama inundado por proyectos animados o computarizados.\n“La serie se inspira en los paisajes, la flora y la fauna, combina escenografía real con entornos digitales. El foco está puesto en la resolución de problemas y los elementos musicales”.\n',
#   'locationTags': 'Morko y Mali ofrece diversión infantil',
ot Robbie\nHillary Clinton\nSean Penn\nFernando del Solar\nMelania Trump\nMarion Cotillard\nTom Hiddleston\n\xa0\nSeries con mayor tendencia de búsqueda:\nEl Señor de los Cielos\nDragon Ball Super\nSoy Luna\nStranger Things\nThe Walking Dead\nYo Soy Frankie\nHasta que te conocí\nLuke Cage\n1000 maneras de morir\nLadybug\n\xa0\nGadgets con mayor tendencia de búsqueda:\n\xa0\niPhone 7\niPhone SE\nGalaxy J7\niPhone 6s\nMoto G4 Plus\nMoto Z\nNintendo Switch\nMoto X Play\nGalaxy S7\nMoto Z Play\n\xa0\nVideojuegos con mayor tendencia de búsqueda:\nPokémon Go\nSlither.io\nAgar.io\nRoblox\nDiep.io\nWarcraft\nFIFA 17\nOverwatch\nSplix.io\nClash Royale\n\xa0\n¿Qué?\n¿Qué es el Brexit?\n¿Qué carros no circulan hoy?\n¿Qué es el zika?\n¿Qué es Pokémon Go?\n¿Qué es Simsimi?\n¿Qué pasa si gana Trump?\n¿Qué se celebra el 12 de octubre?\n¿Qué es Panama Papers?\n¿Qué es golpe de Estado?\n¿Qué es la reforma educativa?\n\xa0\n¿Cómo?\n¿Cómo descargar Pokémon Go?\n¿Cómo van las elecciones en USA?\n¿Cómo cambiar la contraseña del módem?\n¿Cómo murió Juan Gabriel?\n¿Cómo programar la TV?\n¿Cómo funciona Uber?\n¿Cómo afecta el Brexit a México?\n¿Cómo armar un cubo Rubik?\n¿Cómo murió Renato Lopez?\n¿Cómo murió Mario Almada?\n\xa0\n¿Cómo se obtienen las listas de “El año en búsquedas”?\nLas listas son conformadas mediante la exploración y análisis de las miles de millones de búsquedas realiza ...
#   'locationTags': '\nlo más buscado, Google 2016, #YearInSearch, Pokémon GO, Juegos Olímpicos de Río 2016, Juan Gabriel, Elecciones Estados Unidos, Sliter.io, Eurocopa, Copa América 2016, Deadpool, iPhone 7, donald trump ',
#   'locationTitle': '\n\nLo más buscado en Google en 2016\n\n',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/articulo/espectaculos/farandula/2016/07/27/kaori-momoi-con-el-manga-no-pasa-nada',
#   'locationBody': "\n[email\xa0protected]/* <![CDATA[ */!function(t,e,r,n,c,a,p){try{t=document.currentScript||function(){for(t=document.getElementsByTagName('script'),e=t.length;e--;)if(t[e].getAttribute('data-cfhash'))return t[e]}();if(t&&(c=t.previousSibling)){p=t.parentNode;if(a=c.getAttribute('data-cfemail')){for(e='',r='0x'+a.substr(0,2)|0,n=2;a.length-n;n+=2)e+='%'+('0'+('0x'+a.substr(n,2)^r).toString(16)).slice(-2);p.replaceChild(document.createTextNode(decodeURIComponent(e)),c)}p.removeChild(t)}}catch(u){}}()/* ]]> */\nSan Miguel de Allende.— Kaori Momoi contesta rápido: “Los japoneses se están esforzando en otro cine distinto al que ya está basado en el manga y nos está consumiendo”.\n“Nosotros, viendo cine, lo que queremos es ver la vida de una persona y que eso te cambie la vida, ¡pero en el manga no pasa nada!, de alguna manera no incluyen sentimiento”.\nEl nombre de la actriz puede no decir mucho, pero sí se identifica como una de las estelares en Memorias de una geisha y quien ha trabajado con directores como Akira Kurosawa (Kagemusha: la sombra del guerrero), la cosa cambia.\nProviene de un país de donde han salido las mejores cintas de terror en la última década, pero también del que personajes como Dragon Ball y Supercampeones han saltado para adueñarse del mundo.\n“Hay dinero con el manga, se gana bastante”, indica.\nMomoi de 64 años (45 de ellos dedicados a la actuación) está de buen humor. Intenta saludar en español con un “hola, mucho gusto”, para luego sonreír y sentarse en el salón de un hotel de esta localidad.\nHabla inglés, pero prefiere tener un intérprete japonés-español para que las ideas no se pierdan en un idioma no materno para ambas partes.\nEl viernes, durante la apertura del Guanajuato International Film Festival en su sede de San Miguel de Allende, recibió un homenaje a su trayectoria. Junto con Dolores Heredia recorrió las calles del lugar a bordo de una calandria y seguido por baile y música.\nY como sorpresa presentó en el Jardín Principal y al aire libre, el corto sobre persecución china en México, que protagoniza bajo la dirección de Carlos Bolado y forma parte del proyecto La habitación, de próximo estreno.\n“Le dije a Sarah (Hoch, directora del certamen), por qué no lo intentamos. Al final de cuenta un corto es sólo hacerlo, no había nada más que eso, en la parte del arte fue muy profesional todo el equipo (de rodaje), aunque luego por ejemplo había una noticia anunciando que algo se vende y yo dije, no, eso no es chino, eso es japonés”, rió la actriz, quien, dijo, conserva sus premios en su oficina.\n",
#   'locationTags': '\nKaori Momoi, Guanajuato Film Fest 2016 ',
#   'locationTitle': '\n\nKaori Momoi: con el manga no pasa nada\n\n',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/articulo/espectaculos/cine/2016/03/20/zetina-y-uribe-vuelan-con-su-voz',
#   'locationBody': "\n[email\xa0protected]/* <![CDATA[ */!function(t,e,r,n,c,a,p){try{t=document.currentScript||function(){for(t=document.getElementsByTagName('script'),e=t.length;e--;)if(t[e].getAttribute('data-cfhash'))return t[e]}();if(t&&(c=t.previousSibling)){p=t.parentNode;if(a=c.getAttribute('data-cfemail')){for(e='',r='0x'+a.substr(0,2)|0,n=2;a.length-n;n+=2)e+='%'+('0'+('0x'+a.substr(n,2)^r).toString(16)).slice(-2);p.replaceChild(document.createTextNode(decodeURIComponent(e)),c)}p.removeChild(t)}}catch(u){}}()/* ]]> */\nLa evolución dice que los dinosaurios se convirtieron en aves para sobrevivir, pero ahora son los humanos quienes apuntan a tener plumas y alas.\nAl menos eso ocurre con los actores mexicanos Luz María Zetina y Adrián Uribe, quienes prestan sus voces a los enojones Angry Birds, personajes surgidos del videojuego.\nElla será Matilda, un ave que ha dominado su ira y que ahora pretende encauzar a los demás.\nÉl es Red, el rojo de mal humor que desde pequeño sufrió acciones moldeadoras de su carácter.\n“Desde hace mucho tiempo había hecho casting para estar en el doblaje de películas pero no me había quedado”, comenta Zetina, previo a entrar al estudio de grabación de voz.\n“Tengo tres hijas y ellas serán los jueces más difíciles de este trabajo”, agrega sonriente.\nAngry Birds, la película, explicará por qué los personajes siempre intentan acabar con los cerdos.\nEn el filme se verá cómo los porcinos comienzan a robarse los huevos de las aves e intentan tirar sus casas.\nEn el videojuego, donde nadie habla, sólo se escuchan sonidos. Su popularidad ha dado para varias versiones con diferentes niveles de dificultad y ya en años anteriores se han lanzado algunos cortos animados en donde se narra de dónde viene la rivalidad entre pájaros y cerdos.\nEl lanzamiento de la película está programado para el 13 de mayo.\nPara entonces, seguramente, Adrián Uribe no habrá pasado ningún nivel del juego.\n“La verdad es que no soy muy bueno”, acepta entre risas al hablar de este videojuego en donde se tiene que lanzar a los pájaros mediante una resortera para primero derumbar los fuertes que construyen los cerdos y luego aniquilarlos, lo cual sucede en escenarios tan cotidianos como jardines y otros tan asombrosos como el espacio.\n“Mi hijo es el bueno en eso, este personaje es amargado, medio irónico, pero en el fondo es bueno”, apunta Adrián Uribe,\nJunto a ambos actores también estará Rubén Cerda como Bomb, el volátil ser que explota cada que sufre una emoción fuerte.\nSu sumará el conductor de radio y televisión, Faysi, que interpretará al locuaz amarillo Chuck.\nTodo el doblaje de los personajes en México estará bajo la dirección de Mario Castañeda, quien ha sido narrador en la serie ochentera Los años maravillosos, la voz de Goku en Dragon Ball Z y del actor Bruce Willis en varias de sus películas.\n“Aquí nadie está por ser amigo de, o porque hayan estado en su casa sin hacer nada”, dice el veterano y experimentado actor de doblaje.\nExplica además que el trabajo se hace pensando en el máximo nivel de excelencia para corresponder con los estándares de la película.\n“Se hace casting y no hay ninguna frase que se escuche y haya quedado con el ‘bueno, ahí más o menos’”, subraya el especialista, al abundar sobre la controversia entre star talent (contratación de famosos para las voces principales) y actores de doblaje.\n“Los tres personajes principales tiene voces armónicas entre sí, una es aguda, otra media y una más grave”, detalla Castañeda.\nAngry Birds fue creado en 2009 y tuvo tanto éxito internacional, que cuatro años después se convirtió en serie bajo el esquema On Demand. En 18 meses registró 3 mil millones de vistas, de acuerdo con Sony, empresa que distribuirá el largometraje.\n",
#   'locationTags': 'N/A',
#   'locationTitle': '\n\nZetina y Uribe vuelan con su voz \n\n',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/articulo/espectaculos/musica/2016/08/15/japon-pop-y-rock-desde-el-otro-lado-del-mundo',
#   'locationBody': "\n[email\xa0protected]/* <![CDATA[ */!function(t,e,r,n,c,a,p){try{t=document.currentScript||function(){for(t=document.getElementsByTagName('script'),e=t.length;e--;)if(t[e].getAttribute('data-cfhash'))return t[e]}();if(t&&(c=t.previousSibling)){p=t.parentNode;if(a=c.getAttribute('data-cfemail')){for(e='',r='0x'+a.substr(0,2)|0,n=2;a.length-n;n+=2)e+='%'+('0'+('0x'+a.substr(n,2)^r).toString(16)).slice(-2);p.replaceChild(document.createTextNode(decodeURIComponent(e)),c)}p.removeChild(t)}}catch(u){}}()/* ]]> */\nUnas adolescentes ataviadas con máscaras de zorro ejecutan con energía pasos de baile al ritmo de las notas de heavy metal que sacuden sus ampones vestidos en rojo y negro, un musculoso luchador vestido de porrista asombra con sus guturales y una diva virtual, cuya voz es emitida desde un programa de computadora, enloquece con un holograma como figura.\n“¡Ankoru! ¡ankoru!” (¡otra!, ¡otra!) gritan los mexicanos, que no quieren
#   'locationBody': "\n[email\xa0protected]/* <![CDATA[ */!function(t,e,r,n,c,a,p){try{t=document.currentScript||function(){for(t=document.getElementsByTagName('script'),e=t.length;e--;)if(t[e].getAttribute('data-cfhash'))return t[e]}();if(t&&(c=t.previousSibling)){p=t.parentNode;if(a=c.getAttribute('data-cfemail')){for(e='',r='0x'+a.substr(0,2)|0,n=2;a.length-n;n+=2)e+='%'+('0'+('0x'+a.substr(n,2)^r).toString(16)).slice(-2);p.replaceChild(document.createTextNode(decodeURIComponent(e)),c)}p.removeChild(t)}}catch(u){}}()/* ]]> */\nLa diversión infantil no sólo se basa en Pokémon, Dragon Ball o cualquier otro contenido proveniente de Asia.\nTamién existen transmisiones que apelan a la conservación del medio ambiente, el desarrollo de las facultades psicomotrices y hasta buscan hacer divertidas las matemáticas.\nUna de ellas es Morko & Mali, nueva producción de Disney Junior que estrenará el 16 de julio y que, a través de aventuras selváticas, busca crear conciencia sobre el planeta en los más pequeños del hogar.\nCon ayuda de elementos musicales y teniendo como fondo la selva del Amazonas, los protagonistas buscarán hacer divertidas aquellas cosas que en ocasiones a los niños les resultan no muy agradables.\n“Buscamos que los niños descubran que hay muchas cosas que desconocen y que pueden resultar divertidas, queremos que vean que salir a la naturaleza puede ser una gran aventura, que la imaginación es poderosa y que aprender cosas nuevas es muy entretenido”, dijo en su visita a México Agustina Vera, protagonista de la serie.\nEl programa de 26 capítulos fue grabado en Buenos Aires y cuenta con elementos de música pop y marionetas en forma de animales de la selva para hacer atractivo a los espectadores cada aventura de los protagonistas.\nJunto a Agustina, Tomás Ottaviano, quien interpreta a Morko, explicó que el programa infantil acercará a los niños a una diversión distinta en un panorama inundado por proyectos animados o computarizados.\n“La serie se inspira en los paisajes, la flora y la fauna, combina escenografía real con entornos digitales. El foco está puesto en la resolución de problemas y los elementos musicales”.\n",
#   'locationTags': '\nMorko y Mali, series de televisión, disney channel ',
#   'locationTitle': '\n\nMorko y Mali ofrece diversión infantil más allá de Pokémon \n\n',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/articulo/cartera/telecom/2016/06/7/en-mexico-30-de-los-ninos-ven-contenidos-por-internet',
#   'locationBody': '\nEn México, el 30% de los niños consumen contenidos a través de internet aunque la televisión abierta sigue siendo el principal medio de acceso a contenidos con 82% de los infantes.\nLo que los niños consumen en internet son "videos musicales, Dragon Ball Z, Hola soy Germán, fernanfloo y videos chistosos", precisó María Lizarraga, titular de la Unidad de Medios y Contenidos Audiovisuales del Instituto Federal de Telecomunicaciones (IFT).\nDurante el Foro de Contenidos de Radio y Televisión para Niñas y Niños, Lizárraga detalló que de los 930 niños encuestados de entre siete y 12 años, 48% ven solos los contenidos por internet y 49% lo hacen desde un teléfono celular.\n\xa0\ncfe\n',
#   'locationTags': '\nIFT, internet ',
#   'locationTitle': '\n\nEn México, 30% de los niños ven contenidos por internet\n\n',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/articulo/espectaculos/television/2016/07/12/anime-imperio-millonario',
#   'locationBody': "\n[email\xa0protected]/* <![CDATA[ */!function(t,e,r,n,c,a,p){try{t=document.currentScript||function(){for(t=document.getElementsByTagName('script'),e=t.length;e--;)if(t[e].getAttribute('data-cfhash'))return t[e]}();if(t&&(c=t.previousSibling)){p=t.parentNode;if(a=c.getAttribute('data-cfemail')){for(e='',r='0x'+a.substr(0,2)|0,n=2;a.length-n;n+=2)e+='%'+('0'+('0x'+a.substr(n,2)^r).toString(16)).slice(-2);p.replaceChild(document.createTextNode(decodeURIComponent(e)),c)}p.removeChild(t)}}catch(u){}}()/* ]]> */\nChile.—A 30 años de su primera transmisión televisiva, Dragon Ball se posiciona como una de las series animadas japonesas (anime) más populares de la historia. Si bien la serie alcanzó en 1999 un récord de audiencia de 1.7 millones de telespectadores durante uno de sus capítulos transmitidos a través Cartoon Network, sus inicios se remontan a las historietas (mangas).\nUn ejemplo de esto es que Dragon Ball vendió 156 millones de copias de sus cómics en Japón y más de 230 millones a nivel mundial. De igual forma, en lo que va del año, el concepto, apoyado por su nueva animación Dragon Ball Super, lanzada en julio de 2015, ha conseguido ingresos por 337 mil millones de dólares; 49 mil 700 corresponden a las ventas de juguetes.\nLa franquicia creada en 1997, Digimon, la cual tiene sus orígenes en el Tamagotchi y que debutó en la televisión en 1999, es otra de las que ha logrado perpetuarse en el tiempo y seguir generando ingresos. Un ejemplo de esto es que para septiembre de este año está programado que la serie de monstruos digitales lance la tercera película de su más reciente serie, mientras que la anterior, Digimon Adventure tri.: Ketsui logró recaudar más de 1 millón de dólares durante sus primeras tres semanas en Japón. En tanto, la serie animada contó con siete temporadas en la televisión, las cuales se transmitieron de 1999 a 2012. De igual forma, los videojuegos de Digimon fueron lanzados para PlayStation y para otras consolas portátiles como Game Boy.\nLa serie creada en 1992, Sailor Moon, es otra de las que ha logrado mantener su imperio con el paso de los años. Y es que actualmente la franquicia genera ingresos por 5 mil millones de dólares sólo por concepto de merchandising. Asimismo, la animación alcanzó tal popularidad que incluso logró presencia en más de 50 países y sus historietas han sido traducidas en más de 17 idiomas. Tal fue la trascendencia que generó la serie animada original de 200 capítulos, que en 2014 se estrenó Crystal, en donde su primer episodio tuvo más de un millón de vistas.\nLa franquicia Pokémon fue creada alrededor de 1995 y desde entonces se transformó en un negocio redondo. Si para 1999 generaba ingresos por 3 mil millones de dólares, para 2015 esa cifra ya alcanzaba los 57 mil millones de dólares. Esto, gracias a las grandes sumas de dinero que la compañía logró ganar a través de sus películas —las cuales registraron ingresos por 927 millones de dólares— y las ganancias de algunos de sus videojuegos, cartas coleccionables, merchandising y el anime.\nTal éxito ha alcanzado la franquicia que sus ingresos han ido aumentando a tasas de un 15% anuales. Ahora, el concepto ha vuelto a sorprender de la mano de Nintendo con el lanzamiento el pasado 5 de julio del juego Pokémon Go, el cual alcanzó más de 50 mil descargas a través de App Store y más de 60 mil en Google Store en las primeras 24 horas desde su estreno en Japón, Australia, Nueva Zelanda y, un día después, en Estados Unidos.\nLas acciones de Nintendo volvieron a dispararse ayer, aumentando en 7 mil 500 millones de dólares la capitalización bursátil de la compañía en dos días, porque los inversores aclamaron el éxito de la app que conjuga la antigua franquicia de juegos con realidad aumentada, la cual permite a los jugadores caminar por barrios reales mientras buscan personajes virtuales de Pokemon en las pantallas de sus smartphones. De acuerdo a SimilarWeb, su tasa de usuarios diarios activos ha igualado a la de  ...
#   'locationTags': '\namazon, renueva, tienda de juguetes, portal, online ',
#   'locationTitle': '\n\nAmazon renueva su tienda de juguetes\n\n',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/articulo/techbit/2016/04/7/dragon-ball-z-extreme-butoden-estrena-multiplayer-online',
#   'locationBody': '\nDragon Ball Z: Extreme Butoden fue lanzado originalmente en Japón en diciembre pasado, pero lamentablemente no tenía un modo Multiplayer Online, por lo que afectó sus ventas, así que Bandai Namco confirmó una actualización del título saldrá hoy,\xa0siete de abril en\xa0Europa con el nombre\xa0“The Extreme Patch”.\nEl reajuste del juego también añade un modo de entrenamiento para aprender a utilizar todas las habilidades de los personajes, un modo Survival que pondrá aprueba tus habilidades. Asimismo agregará más personajes asistentes como Gokú en su tractor (que aparece al principio de la nueva serie Dragon Ball Super) y sobre todo, correcciones en estilos de pelea de los luchadores, que causaba errores y bugs.\nAquí está el video que lanzó la empresa de videojuegos anunciando el parche:\n\n',
# ...
#  {'link': 'http://www.eluniversal.com.mx/computacion-tecno/2014/microsoft-plaza-entretenimiento-videojuego-concurso-cosplay-92731.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://dev.eluniversalqueretaro.mx/content/como-convertirse-en-cosplayer-profesional-0',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/900486.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://dev.eluniversalqueretaro.mx/vida-q/02-01-2013/dan-voz-al-cine',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/115071.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversalmas.com.mx/notas/2012/01/826288.php',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/684667.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/ciudad/105681.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/internacional/76922.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/cultura/71036.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://dev.eluniversalqueretaro.mx/vida-q/19-06-2013/nando-murio-en-la-jaula',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/909048.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/901850.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/911821.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/105803.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/119916.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/116902.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/deportes/137001.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/101128.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/710037.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://dev.eluniversalqueretaro.mx/vida-q/11-06-2013/dibujar-es-mi-vida-sens-oc',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.elgrafico.mx/notas/911166.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.elgrafico.mx/notas/97304.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/articulos/54097.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/608849.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.elgrafico.mx/notas/96561.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/89355.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/85180.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/574800.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/609259.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/89996.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/estilos/66127.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/86104.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/85386.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/668533.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/584657.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/87638.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/articulos/57974.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/89340.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/543213.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/647438.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/96514.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/80462.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://fotos.eluniversal.com.mx/coleccion/muestra_fotogaleria.html?idgal=3278',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/298143.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/453009.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/80327.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.elgrafico.mx/notas/67095.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.elgrafico.mx/notas/531360.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.elgrafico.mx/notas/84386.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/articulos/35049.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/264272.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/531212.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/80747.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/264187.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/474402.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/68879.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/80609.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/423808.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/80537.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/ciudad/75922.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/columnas/56189.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/98672.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/primera/16704.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/cultura/25019.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/nacion/103722.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/105463.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/96627.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/53982.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/cultura/24467.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/38891.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/cultura/23481.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/34088.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/179641.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/deportes/62392.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/cultura/28740.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/nacion/90196.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/35999.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/cultura/23470.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/finanzas/30853.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/222596.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/232368.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/5786.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/primera/1727.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/columnas/7120.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/estados/17538.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/notas/39445.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/21689.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/20009.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/7147.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/2654.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/nacion/20471.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/cultura/6828.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/espectaculos/4322.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'},
#  {'link': 'http://www.eluniversal.com.mx/nacion/20516.html',
#   'locationBody': 'N/A',
#   'locationTags': 'N/A',
#   'locationTitle': 'N/A',
#   'query': 'Dragon Ball'}]

# %%
def visitPage(page,newspaper):
    if newspaper["visitType"] == "pureRequest":
        content = requests.get(page).content
    elif newspaper["visitType"] == "JavascriptEnabled":
        if not sess: 
            sess = dryscrape.Session(base_url = newspaper["searchUrl"])
        content = sess.visit("/"+page).body
    content = BeautifulSoup(content)
    return content

# %%
def extractMaxParamValue(content,newspaper):
    totalParamValues = {}
    for param in newspaper["paginationParams"]:
        locationText = textExtract(content, newspaper["paginationParams"][param]["totalLocationName"])
        value = int(eval(newspaper["paginationParams"][param]["totalLocationOps"].replace("locationText",'"""'+locationText+'"""')))
        totalParamValues[param] = value
    return totalParamValues

# %%
def domTranslate(expression):
    if "#" in expression:
        tag, tag_id = expression.split("#")
        return tag, "id", tag_id
    elif "." in expression:
        tag, tag_class = expression.split(".")
        return tag, "class", tag_class
    else:
        raise "No Id or Class symbol found"
    return None

# %%
newspaper["searchLinksBody"] = "div#IzqDisplayColumn"

# %%
def linkAppend(content, newspaper):
    tag, tagType, tagName = domTranslate(newspaper["searchLinksBody"])
    return list(set([link["href"] for link in content.find(tag,{tagType:tagName}).findAll("a")]))

# %%
newspaper["article"] = {"locationBody":"div.field-type-text-with-summary", "locationTitle":"div.pane-node-title", "locationTags":"div.field-name-field-tags"}

# %%
def textExtract(content, domObject):
    tag, tagType, tagValue = domTranslate(domObject)
    try:
        content.find(tag, {tagType:tagValue})
        locationText = content.find(tag, {tagType:tagValue}).text
    except: 
        locationText = "N/A"
    return locationText

# %%
def extractPageStories(content, newspaper,searchData):
    stories = []
    links = linkExtractor(content, newspaper)
    for link in links:
        story = {}
        content = visitPage(link,newspaper)
        story["link"] = link
        story["query"] = searchData["query"]
        for articleSection in newspaper["article"]:
            domSection = newspaper["article"][articleSection]
            story[articleSection] = textExtract(content, domSection)
        stories.append(story)
    return stories
